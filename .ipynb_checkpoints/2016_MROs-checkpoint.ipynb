# %%
import pandas as pd

# %%
# !ls
# Out:
# 16eofinextract990.dat 16eofinextractez.dat  2016_MROs.ipynb

# %%
df = pd.read_csv('16eofinextract990.dat', sep=' ')
df.head()
# Out:
#   elf        EIN  tax_pd  subseccd s501c3or4947a1cd schdbind  \
# 0   Y  382032501  201506         3                Y        N
# 1   Y  263010938  201412         3                Y        N
# 2   Y  942746487  201506         3                Y        Y
# 3   Y  112889774  201506         3                Y        Y
# 4   Y  263416084  201506         3                Y        Y
#
#   politicalactvtscd lbbyingactvtscd subjto6033cd dnradvisedfundscd    ...      \
# 0                 N               N            N                 N    ...
# 1                 N               N            N                 N    ...
# 2                 N               N            N                 N    ...
# 3                 N               N            N                 N    ...
# 4                 N               N            N                 N    ...
#
#   exceeds1pct509 subtotpub509 pubsupplesub509 samepubsuppsubtot509 grsinc509  \
# ...

# %%
df.nonpfrea.value_counts()
# Out:
# 7     99831
# 9     85654
# 0     77668
# 2     15530
# 12     9027
# 3      4030
# 1      3788
# 13     2812
# 14     2618
# 15     2111
# 6      1608
# 8      1534
# 4       571
# 5       354
# 11      346
# 10        1
# Name: nonpfrea, dtype: int64

# %%
mros = df[df['nonpfrea'] == 5]

# %%
mros.head()
# Out:
#      elf        EIN  tax_pd  subseccd s501c3or4947a1cd schdbind  \
# 2716   Y  205582784  201609         3                Y        Y
# 3975   Y  742623309  201608         3                Y        Y
# 5073   Y  450274828  201606         3                Y        Y
# 5887   Y  651026739  201606         3                Y        Y
# 8471   Y  954815593  201512         3                Y        N
#
#      politicalactvtscd lbbyingactvtscd subjto6033cd dnradvisedfundscd  \
# 2716                 N               N            N                 N
# 3975                 N               N            N                 N
# 5073                 N               N            N                 N
# 5887                 N               N            N                 N
# 8471                 N               N            N                 N
#
#         ...     exceeds1pct509 subtotpub509 pubsupplesub509  \
# 2716    ...                  0            0               0
# ...
